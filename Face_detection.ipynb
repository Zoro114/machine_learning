# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro114/machine_learning/blob/main/Face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread("/content/actor.jpg")
image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(image,cmap="gray")

# %%
face_cascade=cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")

# %%
faces=face_cascade.detectMultiScale(image,1.1,4)

# %%
for (x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),3)

# %%
plt.imshow(image,cmap="gray")
